# %%
import pandas as pd

# %%
! ls
# Out:
# 6505_MLP_predicted_movement.csv
# best_lg_absa.csv
# best_processed_day_level_absa.csv
# data preparation.ipynb
# feature engineering for day-level data.ipynb
# lg_absa.csv
# lg_sa_bert.csv
# lg_sa_roberta.csv
# processed.zip
# processed_absa_price_diff.csv
# processed_day_level_absa.csv
# processed_day_level_sa_bert.csv
# processed_day_level_sa_roberta.csv
# processed_sa_bert_price_diff.csv
# processed_sa_roberta_price_diff.csv
# sample.py

# %% [markdown]
# # load stock price

# %%
def load_stock_df():
    import yfinance as yf

    # Define the stock ticker and date range
    ticker = "LPL"  # Use the correct ticker symbol for LG
    start_date = "2018-01-01"
    end_date = "2018-12-31"

    # Fetch the stock data
    stock_data = yf.download(ticker, start=start_date, end=end_date)

    # Extract the adjusted close prices
    adjusted_close_prices = stock_data["Adj Close"]

    print(adjusted_close_prices)
    return adjusted_close_prices

# %%
lg_stock = load_stock_df()
lg_stock
# Out:
# [*********************100%***********************]  1 of 1 completed
# Date
# 2018-01-02    14.11
# 2018-01-03    14.48
# 2018-01-04    14.29
# 2018-01-05    14.25
# 2018-01-08    14.26
#               ...
# 2018-12-21     7.91
# 2018-12-24     7.99
# 2018-12-26     8.22
# 2018-12-27     8.41
# 2018-12-28     8.13
# Name: Adj Close, Length: 250, dtype: float64
# Date
# 2018-01-02    14.11
# 2018-01-03    14.48
# 2018-01-04    14.29
# 2018-01-05    14.25
# 2018-01-08    14.26
#               ...
# 2018-12-21     7.91
# 2018-12-24     7.99
# 2018-12-26     8.22
# 2018-12-27     8.41
# 2018-12-28     8.13
# Name: Adj Close, Length: 250, dtype: float64

# %%
known_movement_df = lg_stock.diff() # 已知信息：今天的所有情绪信息 + 昨天收盘到今天收盘的价差
print(known_movement_df) # 预测：今天收盘到明天收盘的价差，即：明天的价格movement
to_predict_movement = known_movement_df.shift(-1)
print(to_predict_movement)
# Out:
# Date
# 2018-01-02     NaN
# 2018-01-03    0.37
# 2018-01-04   -0.19
# 2018-01-05   -0.04
# 2018-01-08    0.01
#               ...
# 2018-12-21   -0.02
# 2018-12-24    0.08
# 2018-12-26    0.23
# 2018-12-27    0.19
# 2018-12-28   -0.28
# Name: Adj Close, Length: 250, dtype: float64
# Date
# 2018-01-02    0.37
# 2018-01-03   -0.19
# 2018-01-04   -0.04
# 2018-01-05    0.01
# 2018-01-08   -0.14
#               ...
# 2018-12-21    0.08
# 2018-12-24    0.23
# 2018-12-26    0.19
# 2018-12-27   -0.28
# 2018-12-28     NaN
# Name: Adj Close, Length: 250, dtype: float64

# %%
type(known_movement_df)
# Out:
# pandas.core.series.Series

# %%
# Convert the two series into dataframes
known_movement_df = known_movement_df.to_frame()
known_movement_df.columns = ['known']
to_predict_movement = to_predict_movement.to_frame()
to_predict_movement.columns = ['to_predict']

# %%
type(known_movement_df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # sentiment analysis

# %%
df = pd.read_csv('./processed_day_level_sa_bert.csv', index_col=[0])
df.index.name = 'Date'
df
# Out:
#             positive  negative  neutral  none  count
# Date
# 2018-01-01        10         2        1     0     13
# 2018-01-02        28         7        1     0     36
# 2018-01-03        22        11        1     0     34
# 2018-01-04        24         8        4     0     36
# 2018-01-05        21         5        2     0     28
# ...              ...       ...      ...   ...    ...
# 2018-05-27        12         2        0     0     14
# 2018-05-28        17         7        3     0     27
# 2018-05-29        20         5        2     0     27
# 2018-05-30        24         4        1     0     29
# 2018-05-31        14         2        0     0     16
#
# [151 rows x 5 columns]

# %%
# Convert the index of the df dataframe to DatetimeIndex
df.index = pd.to_datetime(df.index, format='%Y-%m-%d')

# Concatenate the three dataframes on their index
full = pd.concat([df, known_movement_df, to_predict_movement], axis=1, join='inner')

# Set the name of the index column
full.index.name = 'Date'

# Drop any rows with missing values
full.dropna(inplace=True)

# %%
full
# Out:
#             positive  negative  neutral  none  count  known  to_predict
# Date
# 2018-01-03        22        11        1     0     34   0.37   -0.190000
# 2018-01-04        24         8        4     0     36  -0.19   -0.040000
# 2018-01-05        21         5        2     0     28  -0.04    0.010000
# 2018-01-08        24         1        1     0     26   0.01   -0.140000
# 2018-01-09        25         8        5     0     38  -0.14   -0.140000
# ...              ...       ...      ...   ...    ...    ...         ...
# 2018-05-24        14         5        3     0     22  -0.17   -0.040000
# 2018-05-25        14         3        1     0     18  -0.04    0.120000
# 2018-05-29        20         5        2     0     27   0.12    0.010000
# 2018-05-30        24         4        1     0     29   0.01   -0.120000
# 2018-05-31        14         2        0     0     16  -0.12    0.379999
#
# [103 rows x 7 columns]

# %%
full.to_csv('processed_sa_bert_price_diff.csv')

# %% [markdown]
# ## for roberta

# %%
df = pd.read_csv('./processed_day_level_sa_roberta.csv', index_col=[0])
df.index.name = 'Date'
df
# Out:
#             positive  negative  neutral  none  count
# Date
# 2018-01-01        11         1        1     0     13
# 2018-01-02        27         7        2     0     36
# 2018-01-03        24         8        2     0     34
# 2018-01-04        25         7        4     0     36
# 2018-01-05        21         6        1     0     28
# ...              ...       ...      ...   ...    ...
# 2018-05-27        12         1        1     0     14
# 2018-05-28        17         7        3     0     27
# 2018-05-29        21         4        2     0     27
# 2018-05-30        23         4        2     0     29
# 2018-05-31        13         2        1     0     16
#
# [151 rows x 5 columns]

# %%
# Convert the index of the df dataframe to DatetimeIndex
df.index = pd.to_datetime(df.index, format='%Y-%m-%d')

# Concatenate the three dataframes on their index
full = pd.concat([df, known_movement_df, to_predict_movement], axis=1, join='inner')

# Set the name of the index column
full.index.name = 'Date'

# Drop any rows with missing values
full.dropna(inplace=True)

# %%
full
# Out:
#             positive  negative  neutral  none  count  known  to_predict
# Date
# 2018-01-03        24         8        2     0     34   0.37   -0.190000
# 2018-01-04        25         7        4     0     36  -0.19   -0.040000
# 2018-01-05        21         6        1     0     28  -0.04    0.010000
# 2018-01-08        23         2        1     0     26   0.01   -0.140000
# 2018-01-09        27         6        5     0     38  -0.14   -0.140000
# ...              ...       ...      ...   ...    ...    ...         ...
# 2018-05-24        15         6        1     0     22  -0.17   -0.040000
# 2018-05-25        15         1        2     0     18  -0.04    0.120000
# 2018-05-29        21         4        2     0     27   0.12    0.010000
# 2018-05-30        23         4        2     0     29   0.01   -0.120000
# 2018-05-31        13         2        1     0     16  -0.12    0.379999
#
# [103 rows x 7 columns]

# %%
full.to_csv('processed_sa_roberta_price_diff.csv')

# %% [markdown]
# # absa feature engineering

# %%
df = pd.read_csv('./processed_day_level_absa.csv', index_col=[0])
df.index.name = 'Date'
df
# Out:
#             quality_positive  quality_negative  quality_neutral  quality_none
# Date
# 2018-01-01                 4                 0                0             9  \
# 2018-01-02                10                 2                0            24
# 2018-01-03                 5                 4                0            25
# 2018-01-04                 9                 4                0            23
# 2018-01-05                 8                 1                0            19
# ...                      ...               ...              ...           ...
# 2018-05-27                 6                 1                0             7
# 2018-05-28                 7                 5                0            15
# 2018-05-29                 6                 1                0            20
# 2018-05-30                11                 2                0            16
# 2018-05-31                 9                 1                0             6
#
#             connectivity_positive  connectivity_negative
# Date
# 2018-01-01                      0                      1  \
# 2018-01-02                      0                      1
# 2018-01-03                      0                      0
# 2018-01-04                      0                      0
# 2018-01-05                      0                      0
# ...                           ...                    ...
# 2018-05-27                      0                      0
# 2018-05-28                      0                      0
# 2018-05-29                      0                      0
# 2018-05-30                      0                      0
# 2018-05-31                      0                      0
#
#             connectivity_neutral  connectivity_none  usability_positive
# Date
# 2018-01-01                     0                 12                   0  \
# 2018-01-02                     0                 35                   0
# 2018-01-03                     0                 34                   2
# 2018-01-04                     0                 36                   2
# 2018-01-05                     0                 28                   1
# ...                          ...                ...                 ...
# 2018-05-27                     0                 14                   3
# 2018-05-28                     0                 27                   1
# 2018-05-29                     0                 27                   1
# 2018-05-30                     0                 29                   1
# 2018-05-31                     0                 16                   2
#
#             usability_negative  ...  operation performance_none
# Date                            ...
# 2018-01-01                   0  ...                           9  \
# 2018-01-02                   0  ...                          23
# 2018-01-03                   0  ...                          25
# 2018-01-04                   0  ...                          27
# 2018-01-05                   0  ...                          22
# ...                        ...  ...                         ...
# 2018-05-27                   0  ...                           8
# 2018-05-28                   0  ...                          19
# 2018-05-29                   0  ...                          20
# 2018-05-30                   0  ...                          20
# 2018-05-31                   0  ...                          13
#
#             design features_positive  design features_negative
# Date
# 2018-01-01                         1                         0  \
# 2018-01-02                         7                         1
# 2018-01-03                         9                         1
# 2018-01-04                         6                         3
# 2018-01-05                         5                         0
# ...                              ...                       ...
# 2018-05-27                         5                         0
# 2018-05-28                         1                         2
# 2018-05-29                         4                         1
# 2018-05-30                         4                         4
# 2018-05-31                         3                         0
#
#             design features_neutral  design features_none  price_positive
# Date
# 2018-01-01                        0                    12               0  \
# 2018-01-02                        0                    28               4
# 2018-01-03                        0                    24               3
# 2018-01-04                        0                    27               2
# 2018-01-05                        0                    23               3
# ...                             ...                   ...             ...
# 2018-05-27                        0                     9               3
# 2018-05-28                        0                    24               1
# 2018-05-29                        0                    22               2
# 2018-05-30                        0                    21               2
# 2018-05-31                        0                    13               2
#
#             price_negative  price_neutral  price_none  count
# Date
# 2018-01-01               0              0          13     13
# 2018-01-02               1              0          31     36
# 2018-01-03               0              0          31     34
# 2018-01-04               0              0          34     36
# 2018-01-05               0              0          25     28
# ...                    ...            ...         ...    ...
# 2018-05-27               0              0          11     14
# 2018-05-28               0              0          26     27
# 2018-05-29               1              0          24     27
# 2018-05-30               1              0          26     29
# 2018-05-31               0              0          14     16
#
# [151 rows x 37 columns]

# %%
# Convert the index of the df dataframe to DatetimeIndex
df.index = pd.to_datetime(df.index, format='%Y-%m-%d')

# Concatenate the three dataframes on their index
full = pd.concat([df, known_movement_df, to_predict_movement], axis=1, join='inner')

# Set the name of the index column
full.index.name = 'Date'

# Drop any rows with missing values
full.dropna(inplace=True)

# %%
full
# Out:
#             quality_positive  quality_negative  quality_neutral  quality_none
# Date
# 2018-01-03                 5                 4                0            25  \
# 2018-01-04                 9                 4                0            23
# 2018-01-05                 8                 1                0            19
# 2018-01-08                 8                 0                0            18
# 2018-01-09                 8                 3                0            27
# ...                      ...               ...              ...           ...
# 2018-05-24                 7                 3                0            12
# 2018-05-25                 5                 0                0            13
# 2018-05-29                 6                 1                0            20
# 2018-05-30                11                 2                0            16
# 2018-05-31                 9                 1                0             6
#
#             connectivity_positive  connectivity_negative
# Date
# 2018-01-03                      0                      0  \
# 2018-01-04                      0                      0
# 2018-01-05                      0                      0
# 2018-01-08                      0                      0
# 2018-01-09                      0                      0
# ...                           ...                    ...
# 2018-05-24                      0                      0
# 2018-05-25                      0                      0
# 2018-05-29                      0                      0
# 2018-05-30                      0                      0
# 2018-05-31                      0                      0
#
#             connectivity_neutral  connectivity_none  usability_positive
# Date
# 2018-01-03                     0                 34                   2  \
# 2018-01-04                     0                 36                   2
# 2018-01-05                     0                 28                   1
# 2018-01-08                     0                 26                   1
# 2018-01-09                     0                 38                   2
# ...                          ...                ...                 ...
# 2018-05-24                     0                 22                   1
# 2018-05-25                     0                 18                   1
# 2018-05-29                     0                 27                   1
# 2018-05-30                     0                 29                   1
# 2018-05-31                     0                 16                   2
#
#             usability_negative  ...  design features_negative
# Date                            ...
# 2018-01-03                   0  ...                         1  \
# 2018-01-04                   0  ...                         3
# 2018-01-05                   0  ...                         0
# 2018-01-08                   0  ...                         0
# 2018-01-09                   0  ...                         3
# ...                        ...  ...                       ...
# 2018-05-24                   0  ...                         0
# 2018-05-25                   0  ...                         0
# 2018-05-29                   0  ...                         1
# 2018-05-30                   0  ...                         4
# 2018-05-31                   0  ...                         0
#
#             design features_neutral  design features_none  price_positive
# Date
# 2018-01-03                        0                    24               3  \
# 2018-01-04                        0                    27               2
# 2018-01-05                        0                    23               3
# 2018-01-08                        0                    19               3
# 2018-01-09                        0                    28               4
# ...                             ...                   ...             ...
# 2018-05-24                        0                    19               5
# 2018-05-25                        0                    17               5
# 2018-05-29                        0                    22               2
# 2018-05-30                        0                    21               2
# 2018-05-31                        0                    13               2
#
#             price_negative  price_neutral  price_none  count  known
# Date
# 2018-01-03               0              0          31     34   0.37  \
# 2018-01-04               0              0          34     36  -0.19
# 2018-01-05               0              0          25     28  -0.04
# 2018-01-08               0              0          23     26   0.01
# 2018-01-09               0              0          34     38  -0.14
# ...                    ...            ...         ...    ...    ...
# 2018-05-24               0              0          17     22  -0.17
# 2018-05-25               0              0          13     18  -0.04
# 2018-05-29               1              0          24     27   0.12
# 2018-05-30               1              0          26     29   0.01
# 2018-05-31               0              0          14     16  -0.12
#
#             to_predict
# Date
# 2018-01-03   -0.190000
# 2018-01-04   -0.040000
# 2018-01-05    0.010000
# 2018-01-08   -0.140000
# 2018-01-09   -0.140000
# ...                ...
# 2018-05-24   -0.040000
# 2018-05-25    0.120000
# 2018-05-29    0.010000
# 2018-05-30   -0.120000
# 2018-05-31    0.379999
#
# [103 rows x 39 columns]

# %%
full.to_csv('processed_absa_price_diff.csv')

# %%
! ls
# Out:
# data preparation.ipynb
# feature engineering for day-level data.ipynb
# lg_absa.csv
# lg_sa_bert.csv
# lg_sa_roberta.csv
# processed_absa_price_diff.csv
# processed_day_level_absa.csv
# processed_day_level_sa_bert.csv
# processed_day_level_sa_roberta.csv
# processed_sa_bert_price_diff.csv
# processed_sa_roberta_price_diff.csv
# sample.py

# %% [markdown]
# ---

# %%
import pandas as pd
df = pd.read_csv('./best_processed_day_level_absa.csv', index_col=[0])
df.index.name = 'Date'

# Convert the index of the df dataframe to DatetimeIndex
df.index = pd.to_datetime(df.index, format='%Y-%m-%d')

# Concatenate the three dataframes on their index
full = pd.concat([df, known_movement_df, to_predict_movement], axis=1, join='inner')

# Set the name of the index column
full.index.name = 'Date'

# Drop any rows with missing values
full.dropna(inplace=True)

# %%
full
# Out:
#             quality_positive  quality_negative  quality_neutral  quality_none
# Date
# 2018-01-03                 4                 4                0            26  \
# 2018-01-04                 9                 2                0            25
# 2018-01-05                 7                 1                0            20
# 2018-01-08                10                 0                0            16
# 2018-01-09                 9                 2                0            27
# ...                      ...               ...              ...           ...
# 2018-05-24                 6                 2                0            14
# 2018-05-25                 2                 1                0            15
# 2018-05-29                 5                 0                0            22
# 2018-05-30                10                 2                0            17
# 2018-05-31                 5                 1                0            10
#
#             connectivity_positive  connectivity_negative
# Date
# 2018-01-03                      0                      0  \
# 2018-01-04                      0                      0
# 2018-01-05                      0                      0
# 2018-01-08                      0                      0
# 2018-01-09                      0                      0
# ...                           ...                    ...
# 2018-05-24                      0                      0
# 2018-05-25                      0                      0
# 2018-05-29                      0                      0
# 2018-05-30                      0                      0
# 2018-05-31                      0                      0
#
#             connectivity_neutral  connectivity_none  usability_positive
# Date
# 2018-01-03                     0                 34                   1  \
# 2018-01-04                     0                 36                   1
# 2018-01-05                     0                 28                   1
# 2018-01-08                     0                 26                   1
# 2018-01-09                     0                 38                   1
# ...                          ...                ...                 ...
# 2018-05-24                     0                 22                   1
# 2018-05-25                     0                 18                   1
# 2018-05-29                     0                 27                   2
# 2018-05-30                     0                 29                   2
# 2018-05-31                     0                 16                   2
#
#             usability_negative  ...  design features_negative
# Date                            ...
# 2018-01-03                   0  ...                         0  \
# 2018-01-04                   0  ...                         1
# 2018-01-05                   0  ...                         0
# 2018-01-08                   0  ...                         0
# 2018-01-09                   0  ...                         2
# ...                        ...  ...                       ...
# 2018-05-24                   0  ...                         0
# 2018-05-25                   0  ...                         0
# 2018-05-29                   0  ...                         1
# 2018-05-30                   0  ...                         0
# 2018-05-31                   0  ...                         0
#
#             design features_neutral  design features_none  price_positive
# Date
# 2018-01-03                        0                    28               3  \
# 2018-01-04                        0                    29               2
# 2018-01-05                        0                    24               3
# 2018-01-08                        0                    22               3
# 2018-01-09                        0                    31               3
# ...                             ...                   ...             ...
# 2018-05-24                        0                    19               5
# 2018-05-25                        0                    15               4
# 2018-05-29                        1                    23               2
# 2018-05-30                        0                    21               3
# 2018-05-31                        0                    12               2
#
#             price_negative  price_neutral  price_none  count  known
# Date
# 2018-01-03               0              0          31     34   0.37  \
# 2018-01-04               0              0          34     36  -0.19
# 2018-01-05               0              0          25     28  -0.04
# 2018-01-08               0              0          23     26   0.01
# 2018-01-09               1              0          34     38  -0.14
# ...                    ...            ...         ...    ...    ...
# 2018-05-24               0              0          17     22  -0.17
# 2018-05-25               0              0          14     18  -0.04
# 2018-05-29               1              0          24     27   0.12
# 2018-05-30               0              0          26     29   0.01
# 2018-05-31               0              0          14     16  -0.12
#
#             to_predict
# Date
# 2018-01-03   -0.190000
# 2018-01-04   -0.040000
# 2018-01-05    0.010000
# 2018-01-08   -0.140000
# 2018-01-09   -0.140000
# ...                ...
# 2018-05-24   -0.040000
# 2018-05-25    0.120000
# 2018-05-29    0.010000
# 2018-05-30   -0.120000
# 2018-05-31    0.379999
#
# [103 rows x 39 columns]

# %%
full.to_csv('best_processed_absa_price_diff.csv')
